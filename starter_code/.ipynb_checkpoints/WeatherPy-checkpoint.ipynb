# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['ushuaia',
#  'atuona',
#  'nome',
#  'mataura',
#  'zhigansk',
#  'tuktoyaktuk',
#  'aklavik',
#  'bethel',
#  'hermanus',
#  'beroroha',
#  'ancud',
#  'kushima',
#  'saskylakh',
#  'kahului',
#  'tsihombe',
#  'avarua',
#  'bredasdorp',
#  'puerto ayora',
#  'thompson',
#  'bambous virieux',
#  'alliston',
#  'acari',
#  'kodiak',
#  'lavrentiya',
#  'ribeira grande',
#  'adrar',
#  'gillette',
#  'upernavik',
#  'tasiilaq',
#  'dingle',
#  'bosaso',
#  'marcona',
#  'ahipara',
#  'mar del plata',
#  'mitsamiouli',
#  'rawson',
#  'luderitz',
#  'ossora',
#  'rio gallegos',
#  'teya',
#  'ketchikan',
#  'acapulco',
#  'asau',
#  'tymovskoye',
#  'busselton',
#  'suksun',
#  'bandarbeyla',
#  'castro',
#  'yellowknife',
#  'ardakan',
#  'gamba',
#  'hilo',
#  'gushikawa',
#  'punta arenas',
#  'gagino',
#  'attawapiskat',
#  'rikitea',
#  'yar-sale',
#  'batagay',
#  'carnarvon',
#  'nikolskoye',
#  'charcas',
#  'la ronge',
#  'lamego',
#  'tiksi',
#  'dikson',
#  'richards bay',
#  'raudeberg',
#  'san patricio',
#  'tokur',
#  'grand river south east',
#  'tingi',
#  'danilovka',
#  'bluff',
#  'shingu',
#  'okhotsk',
#  'kapaa',
#  'cidreira',
#  'point pleasant',
#  'hasaki',
#  'lamu',
#  'quatre cocos',
#  'severo-kurilsk',
#  'touros',
#  'rockhampton',
#  'sao miguel do iguacu',
#  'albany',
#  'mys shmidta',
#  'kaitangata',
#  'illoqqortoormiut',
#  'college',
#  'krasnoselkup',
#  'taolanaro',
#  'kloulklubed',
#  'mariental',
#  'cape town',
#  'nizhneyansk',
#  'taveta',
#  'klaksvik',
#  'chokurdakh',
#  'butaritari',
#  'baghdad',
#  'chuy',
#  'hualmay',
#  'port blair',
#  'berlevag',
#  'dossor',
#  'barawe',
#  'san carlos',
#  'solnechnyy',
#  'lorengau',
#  'lata',
#  'road town',
#  'westport',
#  'dawei',
#  'ashqelon',
#  'port hardy',
#  'namatanai',
#  'airai',
#  'ereymentau',
#  'souillac',
#  'moose factory',
#  'vao',
#  'tarquinia',
#  'saravan',
#  'barrow',
#  'mahebourg',
#  'mao',
#  'kaeo',
#  'hithadhoo',
#  'jishou',
#  'kozhva',
#  'leh',
#  'shiyan',
#  'pakwach',
#  'cruden bay',
#  'shasta lake',
#  'codrington',
#  'faanui',
#  'hami',
#  'banjar',
#  'clonakilty',
#  'nuuk',
#  'teterow',
#  'belaya gora',
#  'ferme-neuve',
#  'suntar',
#  'saint-philippe',
#  'colesberg',
#  'ambilobe',
#  'guane',
#  'east london',
#  'along',
#  'hobart',
#  'haines junction',
#  'palabuhanratu',
#  'katobu',
#  'dien bien',
#  'srednekolymsk',
#  'namibe',
#  'wattegama',
#  'pevek',
#  'provideniya',
#  'genteng',
#  'guerrero negro',
#  'opuwo',
#  'sao filipe',
#  'bengkulu',
#  'alotau',
#  'saint anthony',
#  'iki-burul',
#  'barentsburg',
#  'kisangani',
#  'jalu',
#  'saint george',
#  'khandyga',
#  'diamantino',
#  'norman wells',
#  'praia',
#  'qaanaaq',
#  'yeletskiy',
#  'port alfred',
#  'bahia blanca',
#  'evensk',
#  'esperance',
#  'muroto',
#  'sisimiut',
#  'santa maria',
#  'te anau',
#  'plerin',
#  'anadyr',
#  'dafeng',
#  'chipinge',
#  'nishihara',
#  'narsaq',
#  'hambantota',
#  'jamestown',
#  'bilibino',
#  'arraial do cabo',
#  'bako',
#  'muros',
#  'dinsor',
#  'ponta do sol',
#  'doba',
#  'severodvinsk',
#  'buzdyak',
#  'neftcala',
#  'kasimbazar',
#  'faya',
#  'yarim',
#  'north bend',
#  'kumluca',
#  'fort-shevchenko',
#  'llanelli',
#  'swellendam',
#  'ciras',
#  'chamba',
#  'laguna',
#  'matara',
#  'fetsund',
#  'traiguen',
#  'tumannyy',
#  'noumea',
#  'xining',
#  'vaini',
#  'thano bula khan',
#  'amderma',
#  'kieta',
#  'alice springs',
#  'odweyne',
#  'loralai',
#  'heinola',
#  'port hedland',
#  'nouakchott',
#  'nurota',
#  'katsuura',
#  'yamasaki',
#  'yabucoa',
#  'dakoro',
#  'cabo san lucas',
#  'scottsburgh',
#  'sinnamary',
#  'lebu',
#  'plettenberg bay',
#  'fuengirola',
#  'victoria',
#  'khatanga',
#  'zhezkazgan',
#  'qax',
#  'goumenissa',
#  'zaria',
#  'new norfolk',
#  'egvekinot',
#  'saleaula',
#  'batagay-alyta',
#  'knysna',
#  'tammisaari',
#  'arlit',
#  'cherskiy',
#  'kuusamo',
#  'alofi',
#  'paita',
#  'san cristobal',
#  'coquimbo',
#  'mantua',
#  'arua',
#  'boende',
#  'aloleng',
#  'abha',
#  'mazamari',
#  'sibolga',
#  'high level',
#  'rohnert park',
#  'pochutla',
#  'hoquiam',
#  'porto seguro',
#  'bur gabo',
#  'alekseyevka',
#  'amparafaravola',
#  'georgetown',
#  'taunsa',
#  'karratha',
#  'ferkessedougou',
#  'noyabrsk',
#  'nanortalik',
#  'bam',
#  'shenjiamen',
#  'cocorit',
#  'warri',
#  'ostrovnoy',
#  'kalmunai',
#  'samarai',
#  'mnogovershinnyy',
#  'carai',
#  'grand baie',
#  'nouadhibou',
#  'uk',
#  'baykit',
#  'tuatapere',
#  'kantilo',
#  'binzhou',
#  'lillooet',
#  'geraldton',
#  'bathsheba',
#  'sorland',
#  'belushya guba',
#  'san luis',
#  'jiblah',
#  'brae',
#  'maningrida',
#  'pierre',
#  'rock sound',
#  'lola',
#  'sitka',
#  'port keats',
#  'beringovskiy',
#  'olafsvik',
#  'sur',
#  'mikkeli',
#  'vila',
#  'salinopolis',
#  'kirakira',
#  'quelimane',
#  'constitucion',
#  'fortuna',
#  'pangnirtung',
#  'caravelas',
#  'lokosovo',
#  'ilulissat',
#  'paamiut',
#  'ati',
#  'ayan',
#  'yingzhong',
#  'kawambwa',
#  'jieshi',
#  'najran',
#  'sayyan',
#  'tiznit',
#  'port elizabeth',
#  'kavieng',
#  'kavaratti',
#  'luau',
#  'horodnytsya',
#  'denau',
#  'impfondo',
#  'emerald',
#  'kushiro',
#  'uyuni',
#  'mareeba',
#  'labuhan',
#  'champerico',
#  'mogadishu',
#  'killybegs',
#  'kisiwani',
#  'bulungu',
#  'katsiveli',
#  'inhambane',
#  'yulara',
#  'hofn',
#  'durres',
#  'samusu',
#  'moreira sales',
#  'kyra',
#  'komsomolskiy',
#  'fereydun kenar',
#  'trairi',
#  'nicoya',
#  'dwarka',
#  'sangar',
#  'longyearbyen',
#  'naze',
#  'pisco',
#  'contai',
#  'nguiu',
#  'talnakh',
#  'dasoguz',
#  'ha giang',
#  'ojinaga',
#  'dickinson',
#  'loei',
#  'waddan',
#  'kruisfontein',
#  'ajaccio',
#  'beloha',
#  'lykhivka',
#  'sovetskiy',
#  'auki',
#  'forbes',
#  'banda aceh',
#  'bulancak',
#  'sambava',
#  'rungata',
#  'kasempa',
#  'oktyabrskiy',
#  'cervo',
#  'liure',
#  'marrakesh',
#  'dalian',
#  'fairbanks',
#  'warrington',
#  'siirt',
#  'lagoa',
#  'axim',
#  'dharan',
#  'chapais',
#  'meadow lake',
#  'abu dhabi',
#  'barguzin',
#  'male',
#  'torbay',
#  'belyy yar',
#  'clayton',
#  'trelew',
#  'blackwater',
#  'sungairaya',
#  'soyo',
#  'waterloo',
#  'poum',
#  'anzio',
#  'leningradskiy',
#  'marawi',
#  'salalah',
#  'vardo',
#  'wangqing',
#  'nyurba',
#  'villanueva de la serena',
#  'gravdal',
#  'metu',
#  'itarema',
#  'christchurch',
#  'kokopo',
#  'bauchi',
#  'cayenne',
#  'darlawn',
#  'tatawin',
#  'moron',
#  'mizdah',
#  'harper',
#  'sao lourenco do sul',
#  'la rioja',
#  'tokmak',
#  'cedar falls',
#  'bonthe',
#  'andenes',
#  'shetpe',
#  'meulaboh',
#  'marienburg',
#  'jumla',
#  'isangel',
#  'vung tau',
#  'kysyl-syr',
#  'omboue',
#  'muncar',
#  'bida',
#  'sofiysk',
#  'huarmey',
#  'gangotri',
#  'aswan',
#  'awjilah',
#  'amahai',
#  'port augusta',
#  'rapid valley',
#  'mirador',
#  'nytva',
#  'west wendover',
#  'gari',
#  'lypova dolyna',
#  'thinadhoo',
#  'mandiana',
#  'fort frances',
#  'karkaralinsk',
#  'buala',
#  'comodoro rivadavia',
#  'ehingen',
#  'port-gentil',
#  'rudnogorsk',
#  'achisay',
#  'yashalta',
#  'loandjili',
#  'qibili',
#  'novorudnyy',
#  'leshukonskoye',
#  'barcelos',
#  'san quintin',
#  'ipixuna',
#  'chake chake',
#  'ngama',
#  'marzuq',
#  'mahanoro',
#  'aykhal',
#  'shaunavon',
#  'riyadh',
#  'kamloops',
#  'harwich',
#  'ust-tsilma',
#  'kathmandu',
#  'cooma',
#  'netanya',
#  'rabak',
#  'ust-nera',
#  'bereda',
#  'chapada dos guimaraes',
#  'saint-prosper',
#  'lazaro cardenas',
#  'pontalina',
#  'tura',
#  'verkhniye kigi',
#  'mezen',
#  'khasan',
#  'conakry',
#  'ruangwa',
#  'canete',
#  'yerbogachen',
#  'katangli',
#  'port macquarie',
#  'kattivakkam',
#  'purpe',
#  'melilla',
#  'kholm',
#  'siloam springs',
#  'vavoua',
#  'saldanha',
#  'maryville',
#  'skjervoy',
#  'clyde river',
#  'manitouwadge',
#  'bardiyah',
#  'astoria',
#  'mendi',
#  'stamsund',
#  'esmeralda',
#  'ambunti',
#  'gerede',
#  'ust-kamchatsk',
#  'kopyevo',
#  'pacifica',
#  'uglovskoye',
#  'vestmannaeyjar',
#  'monte alegre de minas',
#  'turukhansk',
#  'robertsport',
#  'aleksandrovka',
#  'bluefields',
#  'tutoia',
#  'kommunisticheskiy',
#  'bichura',
#  'saint-joseph',
#  'nichlaul',
#  'mount isa',
#  'camacha',
#  'aden',
#  'cockburn town',
#  'oranjemund',
#  'vaitupu',
#  'roebourne',
#  'morgan city',
#  'atka',
#  'aklera',
#  'hamilton',
#  'natal',
#  'smithers',
#  'saint-pierre',
#  'henties bay',
#  'orchard homes',
#  'doha',
#  'verkhnevilyuysk',
#  'maceio',
#  'maniitsoq',
#  'kamenka',
#  'korgen',
#  'kalundborg',
#  'ilovlya',
#  'grand gaube',
#  'newport',
#  'bambanglipuro',
#  'aginskoye',
#  'great falls',
#  'charters towers',
#  'quixada',
#  'vanimo',
#  'mount pleasant',
#  'slave lake',
#  'puerto baquerizo moreno',
#  'kangaba',
#  'fort nelson',
#  'halalo',
#  'kyabe',
#  'baiyin',
#  'zyryanovsk',
#  'kourou',
#  'santa catarina de tepehuanes',
#  'alexandria',
#  'rio tuba',
#  'surakarta',
#  'mildura',
#  'yialos',
#  'sakakah',
#  'kamenskoye',
#  'khilchipur',
#  'valday',
#  'abu kamal',
#  'raychikhinsk',
#  'sola',
#  'nenjiang',
#  'rezekne',
#  'pacific grove',
#  'gualaquiza',
#  'waipawa',
#  'biritiba-mirim',
#  'roma',
#  'verkhnyaya inta',
#  'shubarkuduk',
#  'kanniyakumari',
#  'rabo de peixe',
#  'nador',
#  'ushtobe',
#  'karauzyak',
#  'anloga']

# %%
len(cities)
# Out:
# 618

# %%
api_key = api_keys.api_key
api_key
# Out:
# '31cdd903e524ae4f6614a4d7eef27eec'

# %% [markdown]
# ## Perform API Calls

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + api_key + '&q=' + cities[0] + 

#response = requests.get(url)
#alex = response.json()
#print(alex)

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + api_key +'&q='

# Get weather data

lat = []
temp = []
humidity = []
cloudiness = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each
for city in cities[0:50]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)
   
    
    #wind_speed.append(response['wind']['speed'])

# Try to access key that doesn't exist

    # Get the temperature from the response

# %%
for city in cities[51:100]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[101:150]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[151:200]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[201:250]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[251:300]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[301:350]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[351:400]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[401:450]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[451:500]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[501:550]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[551:600]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
for city in cities[601:618]:
    response = requests.get(url + city).json()
    #print(response['coord'])
    try:
        lat.append(response['coord']['lat'])
    except KeyError:
         lat.append(np.NaN)
# "Catching" the error lets the rest of our code execute
    #print("...But the program doesn't die early!")
    #lat.append(response['coord']['lat'])
    try:
        temp.append(response['main']['temp'])
    except KeyError:
         temp.append(np.NaN)
    #temp.append(response['main']['temp'])
    #humidity.append(response['main']['humidity'])
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
         cloudiness.append(np.NaN)
    #cloudiness.append(response['clouds']['all'])
    try:
        wind_speed.append(response['wind']['speed'])
    except KeyError:
         wind_speed.append(np.NaN)

# %%
data = pd.DataFrame({'lat': lat, 'temp': temp, 'humidity': humidity, 'cloudiness': cloudiness,'wind speed': wind_speed})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-1e598bca07a8> in <module>()
# ----> 1 data = pd.DataFrame({'lat': lat, 'temp': temp, 'humidity': humidity, 'cloudiness': cloudiness,'wind speed': wind_speed})
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7313     # figure out the index, if necessary
#    7314     if index is None:
# -> 7315         index = extract_index(arrays)
#    7316
#    7317     # don't force copy because getting jammed in an ndarray anyway
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    7359             lengths = list(set(raw_lengths))
#    7360             if len(lengths) > 1:
# -> 7361                 raise ValueError('arrays must all be same length')
#    7362
#    7363             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
#data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-dbd883db58b7> in <module>()
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %%
#data.dropna()

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + api_key +'&q= Rome'
#response = requests.get(url).json()
#response['coord']['lat']
